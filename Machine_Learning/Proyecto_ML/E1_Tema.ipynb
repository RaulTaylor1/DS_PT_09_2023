# %% [markdown]
# # Primera entrega ML

# %% [markdown]
# ## Cómo el kilometraje influye en el precio de reventa de un vehículo.

# %% [markdown]
# ### Tema

# %% [markdown]
# En este proyecto estudiaremos un dataset de vehículos usados de la India. Trataremos de predecir el precio de venta de segunda mano de los vehículos.

# %% [markdown]
# Tendiendo en cuenta los datos aportados en el dataset, se intentará predecir el valor de reventa. Se tratará de probar que el número de kilómetros deprecia más a los vehículos más caros y que porcentualmente los vehículos menos costosos retienen más valor.

# %% [markdown]
# ### Datasets y fuentes alternativas de datos
# El dataset contiene datos sobre año de fabricación, kilómetros, tipo de combustible, caja, potencia de motor y media de consumo. COntiene también datos, en apariencia, menos influyentes, como ciudad donde se publica la venta y número de asientos. También se especifica la marca y modelo del vehículo, columna que habrá que tratar para sacar la información valiosa.
# Con estos datos podremos predecir el precio de venta.

# %% [markdown]
# ### Tipo de ML
# Regresión
# ### Target
# - Price
#
# Esta variable muestra el precio por el que se han vendido los coches. En el dataset se muestra en Lakhs, medida utilizada en la India y países vecinos. Se convertirá a euros para facilitar la comprensión de las cifras.
# ### Métricas

# %% [markdown]
# Aún no estoy seguro

# %% [markdown]
# ### Enlaces
#
# Los datos salen de Kaggle y fueron compartidos por los TAs (gracias). Puedes ver el dataset original [aquí](https://www.kaggle.com/datasets/sujay1844/used-car-prices/data).

# %% [markdown]
# ### Este es el dataframe:

# %%
import pandas as pd
df = pd.read_csv('ML_Guide/data/train.csv').drop(columns='Unnamed: 0')
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 1                         Honda Jazz V     Chennai  2011              46000
# 2                    Maruti Ertiga VDI     Chennai  2012              87000
# 3      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 4               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 5842                  Maruti Swift VDI       Delhi  2014              27365
# 5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 5844             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 5845                Maruti Wagon R VXI     Kolkata  2013              46000
# 5846             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...
